# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load model
model = YOLO("best.pt")

# Predict
results = model.predict(r"D:\code\1SU25-DPL\PRJ-weapons_detection\Datasets_weapons\test_modelsaved\test_5.jpg", save=False, conf=0.4)

# Lấy ảnh đã được vẽ bounding box
predicted_img = results[0].plot()

# Hiển thị ảnh
plt.imshow(cv2.cvtColor(predicted_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# image 1/1 D:\code\1SU25-DPL\PRJ-weapons_detection\Datasets_weapons\test_modelsaved\test_5.jpg: 448x640 1 sajam, 1 senpi, 52.3ms
# Speed: 2.2ms preprocess, 52.3ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
